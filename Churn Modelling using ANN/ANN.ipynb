# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Deep Joshi\Desktop\Data Analysis\Deep Learning\Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = df.iloc[:,3:13]
y = df.iloc[:,13]
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
geography = pd.get_dummies(X['Geography'],drop_first=True)
gender = pd.get_dummies(X['Gender'],drop_first=True)
X = pd.concat([X,geography,gender],axis=1)
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0          1               1        101348.88        0      0     0
# 1          0               1        112542.58        0      1     0
# 2          1               0        113931.57        0      0     0
# 3          0               0         93826.63        0      0     0
# 4          1               1         79084.10        0      1     0

# %%
X=X.drop(['Geography','Gender'],axis=1)
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
# Sequential is responsible for creating ANN,CNN and RNN
from keras.layers import Dense
# Dense is used to create hidden layers
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
# Dropout is used for regularization
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=10,kernel_initializer='he_normal',activation='relu',input_dim=11))
classifier.add(Dropout(0.3))

# %%
classifier.add(Dense(units=20,kernel_initializer='he_normal',activation='relu'))
classifier.add(Dropout(0.4))

# %%
classifier.add(Dense(units=15,kernel_initializer='he_normal',activation='relu'))
classifier.add(Dropout(0.2))

# %%
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                220
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15)                315
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 671
# Trainable params: 671
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history=classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=100)
# Out:
# Train on 5359 samples, validate on 2641 samples
# Epoch 1/100
# 5359/5359 [==============================] - 2s 312us/step - loss: 0.6065 - accuracy: 0.7473 - val_loss: 0.4906 - val_accuracy: 0.7955
# Epoch 2/100
# 5359/5359 [==============================] - 1s 229us/step - loss: 0.5077 - accuracy: 0.7899 - val_loss: 0.4711 - val_accuracy: 0.7955
# Epoch 3/100
# 5359/5359 [==============================] - 1s 211us/step - loss: 0.4850 - accuracy: 0.7959 - val_loss: 0.4597 - val_accuracy: 0.7955
# Epoch 4/100
# 5359/5359 [==============================] - 1s 212us/step - loss: 0.4760 - accuracy: 0.7972 - val_loss: 0.4600 - val_accuracy: 0.7963
# Epoch 5/100
# 5359/5359 [==============================] - 1s 211us/step - loss: 0.4625 - accuracy: 0.7974 - val_loss: 0.4451 - val_accuracy: 0.7963
# Epoch 6/100
# 5359/5359 [==============================] - 1s 212us/step - loss: 0.4637 - accuracy: 0.7987 - val_loss: 0.4439 - val_accuracy: 0.7997
# Epoch 7/100
# 5359/5359 [==============================] - 1s 220us/step - loss: 0.4537 - accuracy: 0.8046 - val_loss: 0.4434 - val_accuracy: 0.8069
# Epoch 8/100
# 5359/5359 [==============================] - 1s 215us/step - loss: 0.4492 - accuracy: 0.8059 - val_loss: 0.4342 - val_accuracy: 0.8058
# Epoch 9/100
# 5359/5359 [==============================] - 1s 211us/step - loss: 0.4417 - accuracy: 0.8084 - val_loss: 0.4349 - val_accuracy: 0.8137
# Epoch 10/100
100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3854 - accuracy: 0.8405 - val_loss: 0.3810 - val_accuracy: 0.8395
# Epoch 30/100
# 5359/5359 [==============================] - 1s 197us/step - loss: 0.3911 - accuracy: 0.8364 - val_loss: 0.3807 - val_accuracy: 0.8383
# Epoch 31/100
# 5359/5359 [==============================] - 1s 198us/step - loss: 0.3888 - accuracy: 0.8378 - val_loss: 0.3811 - val_accuracy: 0.8376
# Epoch 32/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3897 - accuracy: 0.8352 - val_loss: 0.3803 - val_accuracy: 0.8406
# Epoch 33/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3889 - accuracy: 0.8339 - val_loss: 0.3820 - val_accuracy: 0.8398
# Epoch 34/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3838 - accuracy: 0.8377 - val_loss: 0.3731 - val_accuracy: 0.8455
# Epoch 35/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3804 - accuracy: 0.8349 - val_loss: 0.3744 - val_accuracy: 0.8451
# Epoch 36/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3921 - accuracy: 0.8319 - val_loss: 0.3761 - val_accuracy: 0.8432
# Epoch 37/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3831 - accuracy: 0.8313 - val_loss: 0.3751 - val_accuracy: 0.8455
# Epoch 38/100
# 5359/5359 [==============================] - 1s 195us/step - loss: 0.3941 - accuracy: 0.8302 - val_loss: 0.3717 - val_accuracy: 0.8451
# Epoch 39/100
# 5359/5359 [==============================] - 1s 195us/step - loss: 0.3812 - accuracy: 0.8414 - val_loss: 0.3745 - val_accuracy: 0.8474
# Epoch 40/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3851 - accuracy: 0.8382 - val_loss: 0.3736 - val_accuracy: 0.8459
# Epoch 41/100
# 5359/5359 [==============================] - 1s 193us/step - loss: 0.3838 - accuracy: 0.8378 - val_loss: 0.3708 - val_accuracy: 0.8432
# Epoch 42/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3854 - accuracy: 0.8369 - val_loss: 0.3703 - val_accuracy: 0.8474
# Epoch 43/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3849 - accuracy: 0.8408 - val_loss: 0.3788 - val_accuracy: 0.8444
# Epoch 44/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3867 - accuracy: 0.8397 - val_loss: 0.3768 - val_accuracy: 0.8455
# Epoch 45/100
# 5359/5359 [==============================] - 1s 193us/step - loss: 0.3800 - accuracy: 0.8418 - val_loss: 0.3792 - val_accuracy: 0.8448
# Epoch 46/100
# 5359/5359 [==============================] - 1s 193us/step - loss: 0.3808 - accuracy: 0.8397 - val_loss: 0.3780 - val_accuracy: 0.8410
# Epoch 47/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3779 - accuracy: 0.8425 - val_loss: 0.3750 - val_accuracy: 0.8421
# Epoch 48/100
# 5359/5359 [==============================] - 1s 203us/step - loss: 0.3856 - accuracy: 0.8364 - val_loss: 0.3770 - val_accuracy: 0.8421
# Epoch 49/100
# 5359/5359 [==============================] - 1s 230us/step - loss: 0.3815 - accuracy: 0.8423 - val_loss: 0.3764 - val_accuracy: 0.8451
# Epoch 50/100
# 5359/5359 [==============================] - 1s 219us/step - loss: 0.3829 - accuracy: 0.8423 - val_loss: 0.3745 - val_accuracy: 0.8482
# Epoch 51/100
# 5359/5359 [==============================] - 1s 228us/step - loss: 0.3839 - accuracy: 0.8393 - val_loss: 0.3713 - val_accuracy: 0.8455
100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3758 - accuracy: 0.8483 - val_loss: 0.3704 - val_accuracy: 0.8535
# Epoch 91/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3762 - accuracy: 0.8466 - val_loss: 0.3677 - val_accuracy: 0.8523
# Epoch 92/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3787 - accuracy: 0.8455 - val_loss: 0.3709 - val_accuracy: 0.8580
# Epoch 93/100
# 5359/5359 [==============================] - 1s 203us/step - loss: 0.3796 - accuracy: 0.8470 - val_loss: 0.3679 - val_accuracy: 0.8523
# Epoch 94/100
# 5359/5359 [==============================] - 1s 199us/step - loss: 0.3706 - accuracy: 0.8518 - val_loss: 0.3593 - val_accuracy: 0.8569
# Epoch 95/100
# 5359/5359 [==============================] - 1s 212us/step - loss: 0.3749 - accuracy: 0.8468 - val_loss: 0.3578 - val_accuracy: 0.8538
# Epoch 96/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3763 - accuracy: 0.8481 - val_loss: 0.3725 - val_accuracy: 0.8535
# Epoch 97/100
# 5359/5359 [==============================] - 1s 198us/step - loss: 0.3825 - accuracy: 0.8397 - val_loss: 0.3709 - val_accuracy: 0.8561
# Epoch 98/100
# 5359/5359 [==============================] - 1s 196us/step - loss: 0.3821 - accuracy: 0.8408 - val_loss: 0.3620 - val_accuracy: 0.8565
# Epoch 99/100
# 5359/5359 [==============================] - 1s 203us/step - loss: 0.3744 - accuracy: 0.8485 - val_loss: 0.3656 - val_accuracy: 0.8554
# Epoch 100/100
# 5359/5359 [==============================] - 1s 198us/step - loss: 0.3793 - accuracy: 0.8423 - val_loss: 0.3712 - val_accuracy: 0.8546

# %%
y_pred=classifier.predict(X_test)
y_pred = y_pred > 0.5

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[1519   76]
#  [ 186  219]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_pred,y_test))
# Out:
# 0.869

# %% [markdown]
# # Hyperparameter Optimization

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, Flatten, LeakyReLU, BatchNormalization, Dropout
from keras.activations import relu, sigmoid

# %%
def create_model(layers, activation):
    model = Sequential()
    for i, nodes in enumerate(layers):
        if i==0:
            model.add(Dense(nodes,input_dim=X_train.shape[1]))
            model.add(Activation(activation))
            model.add(Dropout(0.3))
        else:
            model.add(Dense(nodes))
            model.add(Activation(activation))
            model.add(Dropout(0.3))
            
    model.add(Dense(units = 1, kernel_initializer= 'glorot_uniform', activation = 'sigmoid')) # Note: no activation beyond this point
    
    model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn=create_model, verbose=0)

# %%
layers = [[20], [30, 20]]
activations = ['sigmoid', 'relu']
param_grid = dict(layers=layers, activation=activations, batch_size = [128, 256], epochs=[30])
grid = GridSearchCV(estimator=model, param_grid=param_grid,cv=5)
grid_result = grid.fit(X_train, y_train)

# %%
[grid_result.best_score_,grid_result.best_params_]
# Out:
# [0.8521250009536743,
#  {'activation': 'relu', 'batch_size': 128, 'epochs': 30, 'layers': [30, 20]}]
